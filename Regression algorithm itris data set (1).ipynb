# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df= sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
missing_value = df.isnull().sum()/df.shape[0]*100
missing_value
# Out:
# sepal_length    0.0
# sepal_width     0.0
# petal_length    0.0
# petal_width     0.0
# species         0.0
# dtype: float64

# %%
df.drop_duplicates()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [149 rows x 5 columns]

# %%
df.keys()
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df[df['sepal_length']>4]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df[df['sepal_length']>3]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df[df['petal_length']>4]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 55            5.7          2.8           4.5          1.3  versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
# 149           5.9          3.0           5.1          1.8   virginica
#
# [84 rows x 5 columns]

# %%
df[df['petal_length']>2]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
# 149           5.9          3.0           5.1          1.8   virginica
#
# [100 rows x 5 columns]

# %%
# multi = sns.FacetGrid(df, col ="sepal_length",  hue ="species")

# multi.map(plt.scatter, "petal_length", "sepal_width", edgecolor ="w").add_legend()

# plt.show()

# %% [markdown]
# # Draw outlines around the data points using stripplot linewidth

# %%
sns.set(style = 'whitegrid')
    
sns.stripplot(y="sepal_length", x="species", data = df,
                   linewidth=3,edgecolor='green')
plt.show()

# %%
sns.set(style = 'whitegrid')
    
sns.stripplot(y="petal_length", x="species", data = df,
                   linewidth=3,edgecolor='red')
plt.show()

# %%
sns.pairplot(df, hue ='sepal_length')
plt.show()

# %%
sns.pairplot(df, hue ='species')
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(x="sepal_length",
                y="petal_width",
                data=df)
plt.show()

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=df)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x= "sepal_length",y="petal_length",data = df,hue = "species")
plt.show()

# %%
sns.countplot(x ='species', data = df)
 

plt.show()

# %%
graph=sns.PairGrid(df, hue ='sepal_length')
graph = graph.map_diag(plt.hist)
# type of graph for non-diagonal
graph = graph.map_offdiag(plt.scatter)
# to add legends
graph = graph.add_legend()
plt.show()

# %%
# sns.swarmplot(y = "sepal_width", x = "petal_width", hue = "species", 
#               orient = "h", data = df)
# plt.show()

# %%
# sns.factorplot(x ='sepal_length', y ='sepal_width', data = df)
 
# # Show the plot
# plt.show()

# %%
#This method is used to show point estimates and confidence intervals using scatter plot glyph

sns.pointplot(x = "sepal_width",
              y = "sepal_length",
              data = df)
# show the plot
plt.show()

# %%
sns.violinplot(x ='sepal_length', y ='petal_length', data = df)
plt.show()

# %%
# x = 'sepal_length'
# y = 'sepal_width'
# sns.kdeplot(x)
# plt.show()

# %% [markdown]
# # model 1

# %%
x = df[['sepal_length']]
y = df[['sepal_width']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.4)

# %%
x_train.head()
# Out:
#      sepal_length
# 3             4.6
# 0             5.1
# 17            5.1
# 123           6.3
# 80            5.5

# %%
x_test.head()
# Out:
#      sepal_length
# 34            4.9
# 136           6.3
# 29            4.7
# 129           7.2
# 7             5.0

# %%
y_train.head()
# Out:
#      sepal_width
# 3            3.1
# 0            3.5
# 17           3.5
# 123          2.7
# 80           2.4

# %%
y_test.head()
# Out:
#      sepal_width
# 34           3.1
# 136          3.4
# 29           3.2
# 129          3.0
# 7            3.4

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_pred[0:5]
# Out:
# array([[3.1209378 ],
#        [3.02107006],
#        [3.13520462],
#        [2.95686937],
#        [3.11380439]])

# %%
y_test.head()
# Out:
#      sepal_width
# 34           3.1
# 136          3.4
# 29           3.2
# 129          3.0
# 7            3.4

# %%
y_train.head()
# Out:
#      sepal_width
# 3            3.1
# 0            3.5
# 17           3.5
# 123          2.7
# 80           2.4

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.20698208264030546

# %% [markdown]
# # model 2

# %%
x =df[['sepal_width','petal_width','petal_length']]
y = df[['sepal_length']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.head() ,x_test.head() ,y_train.head() ,y_test.head()
# Out:
# (     sepal_width  petal_width  petal_length
#  52           3.1          1.5           4.9
#  12           3.0          0.1           1.4
#  139          3.1          2.1           5.4
#  77           3.0          1.7           5.0
#  71           2.8          1.3           4.0,
#       sepal_width  petal_width  petal_length
#  86           3.1          1.5           4.7
#  146          2.5          1.9           5.0
#  110          3.2          2.0           5.1
#  33           4.2          0.2           1.4
#  149          3.0          1.8           5.1,
#       sepal_length
#  52            6.9
#  12            4.8
#  139           6.9
#  77            6.7
#  71            6.1,
#       sepal_length
#  86            6.7
#  146           6.3
#  110           6.5
#  33            5.5
#  149           5.9)

# %%
lr2 = LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr2.predict(x_test)

# %%
y_pred[0:5]
# Out:
# array([[6.35263891],
#        [5.97044909],
#        [6.42214344],
#        [5.47485982],
#        [6.40395114]])

# %%
y_test.head()
# Out:
#      sepal_length
# 86            6.7
# 146           6.3
# 110           6.5
# 33            5.5
# 149           5.9

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.11400357811735531

# %% [markdown]
# # model_evaluation

# %%
from sklearn.metrics import accuracy_score

# %%
# x_train_prediction = lr.predict(x_train)
# training_data_accuracy = accuracy_score(x_train_prediction , y_train)

# %%
# print(training_data_accuracy)

# %%
# x_test_prediction = lr3.predict(x_test)
# training_data_accuracy = accuracy_score(x_test_prediction , y_test)

# %%
# print(training_data_accuracy) test data pridiction in 70% is good
