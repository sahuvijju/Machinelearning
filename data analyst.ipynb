# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df= sns.load_dataset("tips")

# %%
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
 df.drop_duplicates()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %%
# deduplicated_df.to_csv('cleaned_dataset.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#  row1 =data.loc[3]
# row2 = data.iloc[3]
# ow1 = data.iloc[[4, 5, 6, 7]]
 
# # retrieving rows by loc method
# row2 = data.iloc[4:8]
df.quantile()
# Out:
# total_bill    17.795
# tip            2.900
# size           2.000
# Name: 0.5, dtype: float64

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
missing_value = df.isnull().sum()/df.shape[0]*100
missing_value
# Out:
# total_bill    0.0
# tip           0.0
# sex           0.0
# smoker        0.0
# day           0.0
# time          0.0
# size          0.0
# dtype: float64

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
# drop null values
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.mean()
# Out:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %%
df.median()
# Out:
# total_bill    17.795
# tip            2.900
# size           2.000
# dtype: float64

# %%
df.mode()
# Out:
#    total_bill  tip   sex smoker  day    time  size
# 0       13.42  2.0  Male     No  Sat  Dinner     2

# %%
#rename 
df.rename(columns={'sex':'gender'})
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df["total_bill"].value_counts()
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: total_bill, Length: 229, dtype: int64

# %%
sns.boxplot([df.total_bill])
plt.show()

# %%
sns.barplot(x = 'sex',y= 'total_bill' ,data =df)
plt.show()

# %%
sns.countplot(data= df, x= "sex" , hue= "tip")
plt.show()

# %%
sns.scatterplot(x= "total_bill", y= "sex" , data = df)
plt.show()

# %%
# sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# sns.set(rc={'figure.figsize':(6,5)})
# sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')

# %%
sns.pairplot(df, hue ='sex')
plt.show()

# %%
sns.lineplot(x="total_bill", y="size", 
             hue="sex", style="sex", 
             data=df) 
  
plt.show()

# %% [markdown]
# # #splitting the data

# %%
# x = df.iloc[:,:4]
# y = df.iloc[:,4]

# %%
# x = df.iloc[:,:1]
# y = df.iloc[:,2]
x = df[['total_bill']]
y = df[['tip']]

# %%
x.head()
# Out:
#    total_bill
# 0       16.99
# 1       10.34
# 2       21.01
# 3       23.68
# 4       24.59

# %%
y.head()
# Out:
#     tip
# 0  1.01
# 1  1.66
# 2  3.50
# 3  3.31
# 4  3.61

# %%
# x = df[['Age']]
# y = df[['Orders']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.20 , random_state = 0)

# %%
x_train
# Out:
#      total_bill
# 7         26.88
# 83        32.68
# 176       17.89
# 106       20.49
# 156       48.17
# ..          ...
# 67         3.07
# 192       28.44
# 117       10.65
# 47        32.40
# 172        7.25
#
# [195 rows x 1 columns]

# %%
y_train
# Out:
#       tip
# 7    3.12
# 83   5.00
# 176  2.00
# 106  4.06
# 156  5.00
# ..    ...
# 67   1.00
# 192  2.56
# 117  1.50
# 47   6.00
# 172  5.15
#
# [195 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
print(y_pred)
# Out:
# [[2.7321953 ]
#  [2.79999268]
#  [2.91621676]
#  [1.73073111]
#  [2.60434881]
#  [1.58545101]
#  [2.76415692]
#  [3.28813383]
#  [2.7864332 ]
#  [4.38451435]
#  [3.47699796]
#  [3.47021823]
#  [2.39127132]
#  [2.28763818]
#  [2.32831661]
#  [3.97288739]
#  [1.83726986]
#  [2.38449158]
#  [2.84745085]
#  [3.26585755]
#  [3.93995723]
#  [3.05471713]
#  [2.57819839]
#  [2.48521912]
#  [2.33703342]
#  [2.61693975]
#  [2.20628132]
#  [3.91477534]
#  [3.4779665 ]
#  [2.55592211]
#  [2.45519457]
#  [2.23727441]
#  [2.52202341]
#  [2.05422148]
#  [2.79999268]
#  [2.32541101]
#  [2.66827205]
#  [2.02903959]
#  [5.7094689 ]
#  [2.57626132]
#  [1.85954614]
#  [2.23243174]
#  [2.54817383]
#  [3.91961801]
#  [2.26439336]
#  [2.67214619]
#  [2.79515001]
#  [3.11864037]
#  [2.68183153]]

# %%
from sklearn.metrics import mean_squared_error
# from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.821309064276629

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
#from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# print(accuracy_score(y_test, y_pred))

# %%
# print(classification_report(y_test, y_pred))

# %%
# print(confusion_matrix(y_test, y_pred))

# %%
# df = pd.read_csv(r"C:\Users\HP\Downloads\Resume Screening1.csv")
# print(df)
# df.to_csv('d\\hjug.csv')

# %%
# counts = df['Category'].value_counts()
# labels = df['Category'].unique()
# plt.figure(figsize=(15,10))
# plt.pie(counts, labels=labels, autopct='%1.1f%%', shadow=True, colors=plt.cm.plasma(np.linspace(0,1,3)))
# plt.show()
df = pd.read_excel("D:\clg pic\salkanpur\Excel Test for MIS.xlsx")
print(df)
# Out:
#      Unnamed: 0         Unnamed: 1             Unnamed: 2  Unnamed: 3  \
# 0           NaN  (1) Test Question                    NaN         NaN
# 1           NaN              Sl No              Emp. Name     ESIC NO
# 2           NaN                  1            VIPIN KUMAR  1113662765
# 3           NaN                  2     RAJESH KUMAR VARMA  1113743433
# 4           NaN                  3     MOHD. NASEER UDDIN  1113757595
# ..          ...                ...                    ...         ...
# 875         NaN                874                 ASHISH  1113792322
# 876         NaN                875  DEVENDER SINGH RAMOLA  1113852882
# 877         NaN                876        MANVENDER SINGH  1113870393
# 878         NaN                877      AMIT KUMAR SHARMA  1113870389
# 879         NaN                878           MUKESH KUMAR  1113875268
#
#     Unnamed: 4   Unnamed: 5                       Unnamed: 6  Unnamed: 7  \
# 0          NaN          NaN                              NaN         NaN
# 1     PAID DAY  ESIC SALARY  Duplicate Count of ESIC Numbers         NaN
# 2           31         8343                              NaN         1.0
# 3         26.5         5908                              NaN         NaN
# 4           31         9047                              NaN         NaN
# ..         ...          ...                              ...         ...
# 875         31         8814                              NaN         NaN
# 876         31         6656                              NaN         NaN
# 877         31         8814                              NaN         NaN
# 878         31         8814                              NaN         NaN
# 879         31         8814                              NaN         NaN
#
#      Unnamed: 8          Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0           NaN         Index match  Index match         NaN
# 1       ESIC NO           Emp. Name  ESIC SALARY         NaN
# 2    1113921622      DASHRATH KUMAR         6441         NaN
# 3    1113757595  MOHD. NASEER UDDIN         9047         NaN
# 4    1113922692                 NaN          NaN         NaN
# ..          ...                 ...          ...         ...
# 875         NaN                 NaN          NaN         NaN
# 876         NaN                 NaN          NaN         NaN
# 877         NaN                 NaN          NaN         NaN
# 878         NaN                 NaN          NaN         NaN
# 879         NaN                 NaN          NaN         NaN
#
# [880 rows x 12 columns]
